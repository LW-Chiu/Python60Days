# %%
import pandas as pd

# %%
import numpy as np

# %%
# 1. 畫出箱型圖，並判斷哪個欄位的中位數在 300-400 之間？

# %%
Data = pd.read_csv('boston.csv')

# %%
Index = Data.set_index('key')

# %%
Index.boxplot()
# Out:
# <AxesSubplot:>

# %%
Data['B'].median()
# Out:
# 391.43

# %%
B = pd.concat([Data['TAX'], Data['B']], axis = 1)

# %%
B.boxplot()
# Out:
# <AxesSubplot:>

# %%
# 2. 畫出散佈圖 x = 'NOX', y = 'DIS'，並說明這兩欄位有什麼關係？

# %%
T = pd.concat([Index['NOX'], Index['DIS']], axis = 1)

# %%
T.plot.scatter(x = 'NOX', y = 'DIS')
# Out:
# <AxesSubplot:xlabel='NOX', ylabel='DIS'>

# %%
# 透過散佈圖，NOX 和 DIS 呈現一指數函數的圖形且這兩項數據有著反向變動的關係
